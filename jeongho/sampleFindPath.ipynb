# %%
15번만
TL1 라벨링 훈련
TS1 원천 훈련
VL1 라벨링 검증
VS1 원천 라벨링

경로
/data/audio1
여기서 시작해서
/data/audio1/unzipped_TL1
이런식

# %%
하위 폴더만 출력

# %%
from pathlib import Path

directory = Path("/data/audio1/unzipped_TS1")

# 하위 폴더만 출력
for folder in directory.rglob("*"):
    if folder.is_dir():
        print(f"Directory: {folder}")
# Out:
# Directory: /data/audio1/unzipped_TS1/TS1
# Directory: /data/audio1/unzipped_TS1/TS1/folder_1
# Directory: /data/audio1/unzipped_TS1/TS1/folder_1/folder_1
# Directory: /data/audio1/unzipped_TS1/TS1/folder_1/folder_4
# Directory: /data/audio1/unzipped_TS1/TS1/folder_1/folder_3
# Directory: /data/audio1/unzipped_TS1/TS1/folder_1/folder_2
# Directory: /data/audio1/unzipped_TS1/TS1/folder_1/folder_1/0032_G1A4E2S0C0_KDD
# Directory: /data/audio1/unzipped_TS1/TS1/folder_1/folder_1/0030_G2A4E2S0C0_PSM
# Directory: /data/audio1/unzipped_TS1/TS1/folder_1/folder_1/0001_G1A3E2S0C0_PSB
# Directory: /data/audio1/unzipped_TS1/TS1/folder_1/folder_1/0019_G2A3E2S0C0_JSY
# Directory: /data/audio1/unzipped_TS1/TS1/folder_1/folder_1/0002_G1A4E2S0C0_LYT
# Directory: /data/audio1/unzipped_TS1/TS1/folder_1/folder_1/0003_G1A4E2S0C0_JCH
# Directory: /data/audio1/unzipped_TS1/TS1/folder_1/folder_1/0015_G2A3E2S0C0_OES
# Directory: /data/audio1/unzipped_TS1/TS1/folder_1/folder_1/0013_G2A2E2S0C0_SHR
# ...

# %%
하위 파일만 출력

# %%
from pathlib import Path

directory = Path("/data/audio1/unzipped_TS1/TS1/folder_1/folder_1/0032_G1A4E2S0C0_KDD")

# 하위 파일만 출력
for file in directory.rglob("*"):
    if file.is_file():
        print(f"File: {file}")
# Out:
# File: /data/audio1/unzipped_TS1/TS1/folder_1/folder_1/0032_G1A4E2S0C0_KDD/0032_G1A4E2S0C0_KDD_001066.wav
# File: /data/audio1/unzipped_TS1/TS1/folder_1/folder_1/0032_G1A4E2S0C0_KDD/0032_G1A4E2S0C0_KDD_000301.wav
# File: /data/audio1/unzipped_TS1/TS1/folder_1/folder_1/0032_G1A4E2S0C0_KDD/0032_G1A4E2S0C0_KDD_000370.wav
# File: /data/audio1/unzipped_TS1/TS1/folder_1/folder_1/0032_G1A4E2S0C0_KDD/0032_G1A4E2S0C0_KDD_000116.wav
# File: /data/audio1/unzipped_TS1/TS1/folder_1/folder_1/0032_G1A4E2S0C0_KDD/0032_G1A4E2S0C0_KDD_001694.wav
# File: /data/audio1/unzipped_TS1/TS1/folder_1/folder_1/0032_G1A4E2S0C0_KDD/0032_G1A4E2S0C0_KDD_001958.wav
# File: /data/audio1/unzipped_TS1/TS1/folder_1/folder_1/0032_G1A4E2S0C0_KDD/0032_G1A4E2S0C0_KDD_001649.wav
# File: /data/audio1/unzipped_TS1/TS1/folder_1/folder_1/0032_G1A4E2S0C0_KDD/0032_G1A4E2S0C0_KDD_001138.wav
# File: /data/audio1/unzipped_TS1/TS1/folder_1/folder_1/0032_G1A4E2S0C0_KDD/0032_G1A4E2S0C0_KDD_001092.wav
# ...
